# %% [markdown]
# # pandasVCFmulti

# %% [markdown]
# ### This example notebook describes simple usage of pandasVCFmulti, a module for parsing VCF files using the pandas library. pandasVCFmulti also handles single sample vcf files.

# %% [markdown]
# # Libraries

# %%
#Import pdVCFsingle package
import matplotlib as plt
import sys
sys.path.append( '../src/multi_sample/' )
from pandasVCFmulti import *
# %config InlineBackend.figure_format = 'retina'
pd.options.mode.chained_assignment = None #supressing the chained assignment warnings

# %% [markdown]
# # Example File Path

# %%
vcf_path = '../test_data/SWGR_titin.vcf.gz'

# %% [markdown]
# # Creating Vcf object

# %% [markdown]
# ### Initiate Vcf object by specifying the sample_id string and the columns the user wants to include for parsing.  Only the CHROM, POS, REF, ALT, and FORMAT fields are required. A parser for the INFO field is in development.  Some VCF files are quite large and will not fit in memory, therefore the user can specify the chunksize which allows iteration through the VCF.

# %%
vcf_chunk = Vcf(vcf_path, sample_id='all', cols=['#CHROM', 'POS', 'REF', 'ALT','FORMAT'], chunksize=1000, n_cores=2)

# %%
vcf_chunk.get_vcf_df_chunk()
# Out:
# 0

# %%
vcf_chunk.df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1000 entries, (2, 179392051, CA, CAA) to (2, 179456668, T, C)
# Columns: 459 entries, CHROM to SHUFFLE_WELLDERLY_EA_453
# dtypes: int64(1), object(458)
# memory usage: 3.5 MB

# %%
vcf_chunk.df.head()
# Out:
#                         CHROM        POS REF  ALT             FORMAT  \
# CHROM POS       REF ALT
# 2     179392051 CA  CAA     2  179392051  CA  CAA  GT:FT:GQ:HQ:DP:AD
#       179392075 GA  GAA     2  179392075  GA  GAA  GT:FT:GQ:HQ:DP:AD
#       179392080 A   T       2  179392080   A    T  GT:FT:GQ:HQ:DP:AD
#       179392237 CA  AT      2  179392237  CA   AT  GT:FT:GQ:HQ:DP:AD
#       179392262 A   G       2  179392262   A    G  GT:FT:GQ:HQ:DP:AD
#
#                         SHUFFLE_WELLDERLY_EA_0 SHUFFLE_WELLDERLY_EA_1  \
# CHROM POS       REF ALT
# 2     179392051 CA  CAA      0/0:.:.:.,.:.:.,.      0/0:.:.:.,.:.:.,.
#       179392075 GA  GAA      0/0:.:.:.,.:.:.,.      0/0:.:.:.,.:.:.,.
#       179392080 A   T        0/0:.:.:.,.:.:.,.      0/0:.:.:.,.:.:.,.
#       179392237 CA  AT       0/0:.:.:.,.:.:.,.      0/0:.:.:.,.:.:.,.
#       179392262 A   G        0/0:.:.:.,.:.:.,.      0/0:.:.:.,.:.:.,.
#
#                         SHUFFLE_WELLDERLY_EA_2 SHUFFLE_WELLDERLY_EA_3  \
# CHROM POS       REF ALT
# 2     179392051 CA  CAA      0/0:.:.:.,.:.:.,.      0/0:.:.:.,.:.:.,.
#       179392075 GA  GAA      0/0:.:.:.,.:.:.,.      0/0:.:.:.,.:.:.,.
#       179392080 A   T        0/0:.:.:.,.:.:.,.      0/0:.:.:.,.:.:.,.
#       179392237 CA  AT       0/0:.:.:.,.:.:.,.      0/0:.:.:.,.:.:.,.
#       179392262 A   G        0/0:.:.:.,.:.:.,.      0/0:.:.:.,.:.:.,.
#
#                         SHUFFLE_WELLDERLY_EA_4              ...                \
# CHROM POS       REF ALT                                     ...
# 2     179392051 CA  CAA      0/0:.:.:.,.:.:.,.              ...
#       179392075 GA  GAA      0/0:.:.:.,.:.:.,.              ...
#       179392080 A   T        0/0:.:.:.,.:.:.,.              ...
#       179392237 CA  AT       0/0:.:.:.,.:.:.,.              ...
#       179392262 A   G        0/0:.:.:.,.:.:.,.              ...
#
#                               SHUFFLE_WELLDERLY_EA_444  \
# CHROM POS       REF ALT
# 2     179392051 CA  CAA              0/0:.:.:.,.:.:.,.
#       179392075 GA  GAA              0/0:.:.:.,.:.:.,.
#       179392080 A   T    1/0:PASS:247:247,247:36:15,21
#       179392237 CA  AT               0/0:.:.:.,.:.:.,.
#       179392262 A   G                0/0:.:.:.,.:.:.,.
#
#                         SHUFFLE_WELLDERLY_EA_445 SHUFFLE_WELLDERLY_EA_446  \
# CHROM POS       REF ALT
# 2     179392051 CA  CAA        0/0:.:.:.,.:.:.,.        0/0:.:.:.,.:.:.,.
#       179392075 GA  GAA        0/0:.:.:.,.:.:.,.        0/0:.:.:.,.:.:.,.
#       179392080 A   T          0/0:.:.:.,.:.:.,.        0/0:.:.:.,.:.:.,.
#       179392237 CA  AT         0/0:.:.:.,.:.:.,.        0/0:.:.:.,.:.:.,.
#       179392262 A   G          0/0:.:.:.,.:.:.,.        0/0:.:.:.,.:.:.,.
#
#                               SHUFFLE_WELLDERLY_EA_447  \
# CHROM POS       REF ALT
# 2     179392051 CA  CAA              0/0:.:.:.,.:.:.,.
#       179392075 GA  GAA              0/0:.:.:.,.:.:.,.
#       179392080 A   T    1/0:PASS:246:246,246:36:14,22
#       179392237 CA  AT               0/0:.:.:.,.:.:.,.
#       179392262 A   G                0/0:.:.:.,.:.:.,.
#
#                         SHUFFLE_WELLDERLY_EA_448 SHUFFLE_WELLDERLY_EA_449  \
# CHROM POS       REF ALT
# 2     179392051 CA  CAA        0/0:.:.:.,.:.:.,.        0/0:.:.:.,.:.:.,.
#       179392075 GA  GAA        0/0:.:.:.,.:.:.,.        0/0:.:.:.,.:.:.,.
#       179392080 A   T          0/0:.:.:.,.:.:.,.        0/0:.:.:.,.:.:.,.
#       179392237 CA  AT         0/0:.:.:.,.:.:.,.        0/0:.:.:.,.:.:.,.
#       179392262 A   G          0/0:.:.:.,.:.:.,.        0/0:.:.:.,.:.:.,.
#
#                               SHUFFLE_WELLDERLY_EA_450  \
# CHROM POS       REF ALT
# 2     179392051 CA  CAA              0/0:.:.:.,.:.:.,.
#       179392075 GA  GAA              0/0:.:.:.,.:.:.,.
#       179392080 A   T    1/0:PASS:264:385,264:31:20,11
#       179392237 CA  AT               0/0:.:.:.,.:.:.,.
#       179392262 A   G                0/0:.:.:.,.:.:.,.
#
#                         SHUFFLE_WELLDERLY_EA_451 SHUFFLE_WELLDERLY_EA_452  \
# CHROM POS       REF ALT
# 2     179392051 CA  CAA        0/0:.:.:.,.:.:.,.        0/0:.:.:.,.:.:.,.
#       179392075 GA  GAA        0/0:.:.:.,.:.:.,.        0/0:.:.:.,.:.:.,.
#       179392080 A   T          0/0:.:.:.,.:.:.,.        0/0:.:.:.,.:.:.,.
#       179392237 CA  AT         0/0:.:.:.,.:.:.,.        0/0:.:.:.,.:.:.,.
#       179392262 A   G          0/0:.:.:.,.:.:.,.        0/0:.:.:.,.:.:.,.
#
#                               SHUFFLE_WELLDERLY_EA_453
# CHROM POS       REF ALT
# 2     179392051 CA  CAA              0/0:.:.:.,.:.:.,.
#       179392075 GA  GAA              0/0:.:.:.,.:.:.,.
#       179392080 A   T    1/0:PASS:198:198,198:32:12,20
#       179392237 CA  AT               0/0:.:.:.,.:.:.,.
#       179392262 A   G                0/0:.:.:.,.:.:.,.
#
# [5 rows x 459 columns]

# %%
#checking stopIteration flag
vcf_chunk.stopIteration
# Out:
# False

# %% [markdown]
# ### Adding Annotations

# %%
# %time vcf_chunk.add_variant_annotations(inplace=True)  #split_columns={'AD':2, 'HQ':2},
# Out:
# CPU times: user 216 ms, sys: 103 ms, total: 319 ms
# Wall time: 3.13 s
# 0

# %%
vcf_chunk.df
# Out:
# Exception RuntimeError: RuntimeError('cannot join current thread',) in <Finalize object, dead> ignored
# Exception in thread Thread-11:
# Traceback (most recent call last):
#   File "/Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/threading.py", line 551, in __bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/zmq/utils/garbage.py", line 34, in run
#     s.bind(self.gc.url)
#   File "socket.pyx", line 444, in zmq.backend.cython.socket.Socket.bind (zmq/backend/cython/socket.c:4076)
#   File "checkrc.pxd", line 21, in zmq.backend.cython.checkrc._check_rc (zmq/backend/cython/socket.c:6032)
# ZMQError: Address already in use
#
# Exception in thread Thread-11:
# Traceback (most recent call last):
#   File "/Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/threading.py", line 551, in __bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/zmq/utils/garbage.py", line 34, in run
#     s.bind(self.gc.url)
#   File "socket.pyx", line 444, in zmq.backend.cython.socket.Socket.bind (zmq/backend/cython/socket.c:4076)
#   File "checkrc.pxd", line 21, in zmq.backend.cython.checkrc._check_rc (zmq/backend/cython/socket.c:6032)
# ZMQError: Address already in use
#                                                     multiallele phase  GT1  \
# CHROM POS       REF ALT   sample_ids
# 2     179392051 CA  CAA   SHUFFLE_WELLDERLY_EA_170            0     /    1
#       179392075 GA  GAA   SHUFFLE_WELLDERLY_EA_52             0     /    1
#       179392080 A   T     SHUFFLE_WELLDERLY_EA_8              0     /    1
#                           SHUFFLE_WELLDERLY_EA_12             0     /    1
#                           SHUFFLE_WELLDERLY_EA_13             0     /    1
#                           SHUFFLE_WELLDERLY_EA_19             0     /    1
#                           SHUFFLE_WELLDERLY_EA_28             0     /    1
#                           SHUFFLE_WELLDERLY_EA_29             0     /    1
#                           SHUFFLE_WELLDERLY_EA_30             0     /    1
#                           SHUFFLE_WELLDERLY_EA_39             0     /    1
#                           SHUFFLE_WELLDERLY_EA_41             0     /    1
#                           SHUFFLE_WELLDERLY_EA_42             0     /    1
#                           SHUFFLE_WELLDERLY_EA_44             0     /    1
#                           SHUFFLE_WELLDERLY_EA_45             0     /    1
#                           SHUFFLE_WELLDERLY_EA_47             0     /    1
#                           SHUFFLE_WELLDERLY_EA_54             0     /    1
#                           SHUFFLE_WELLDERLY_EA_60             0     /    1
#                           SHUFFLE_WELLDERLY_EA_65             0     /    1
#                           SHUFFLE_WELLDERLY_EA_75             0     /    1
#                           SHUFFLE_WELLDERLY_EA_81             0     /    1
#                           SHUFFLE_WELLDERLY_EA_84             0     /    1
#                           SHUFFLE_WELLDERLY_EA_91             0     /    1
#                           SHUFFLE_WELLDERLY_EA_96             0     /    1
#                           SHUFFLE_WELLDERLY_EA_97             0     /    1
#                           SHUFFLE_WELLDERLY_EA_98             0     /    1
#                           SHUFFLE_WELLDERLY_EA_107            0     /    1
#                           SHUFFLE_WELLDERLY_EA_111            0     /    1
#                           SHUFFLE_WELLDERLY_EA_115            0     /    1
#                           SHUFFLE_WELLDERLY_EA_121            0     /    1
#                           SHUFFLE_WELLDERLY_EA_125            0     /    1
# ...                                                         ...   ...  ...
#       179455207 T   C     SHUFFLE_WELLDERLY_EA_441            0     /    1
#                           SHUFFLE_WELLDERLY_EA_442            0     /    1
#       179455303 C   T     SHUFFLE_WELLDERLY_EA_310            0     /    1
#       179455352 C   T     SHUFFLE_WELLDERLY_EA_52             0     /    1
#                           SHUFFLE_WELLDERLY_EA_150            0     /    1
#                           SHUFFLE_WELLDERLY_EA_232            0     /    1
#                           SHUFFLE_WELLDERLY_EA_353            0     /    1
#                           SHUFFLE_WELLDERLY_EA_393            0     /    1
#                           SHUFFLE_WELLDERLY_EA_446            0     /    1
#       179455427 T   C     SHUFFLE_WELLDERLY_EA_280            0     /    1
#                           SHUFFLE_WELLDERLY_EA_405            0     /    1
#       179455502 C   T     SHUFFLE_WELLDERLY_EA_171            0     /    1
#       179455631 G   A     SHUFFLE_WELLDERLY_EA_418            0     /    1
#       179455731 C   G     SHUFFLE_WELLDERLY_EA_252            0     /    1
#                           SHUFFLE_WELLDERLY_EA_310            0     /    1
#       179455777 TCC TT    SHUFFLE_WELLDERLY_EA_69             0     /    1
#                           SHUFFLE_WELLDERLY_EA_146            0     /    1
#       179455928 G   C     SHUFFLE_WELLDERLY_EA_248            0     /    1
#       179455936 AG  A     SHUFFLE_WELLDERLY_EA_257            0     /    1
#       179456000 A   G     SHUFFLE_WELLDERLY_EA_383            0     /    1
#                           SHUFFLE_WELLDERLY_EA_422            0     /    1
#       179456205 T   C     SHUFFLE_WELLDERLY_EA_275            0     /    1
#       179456247 G   GA    SHUFFLE_WELLDERLY_EA_276            0     /    1
#       179456264 A   G     SHUFFLE_WELLDERLY_EA_209            0     /    1
#       179456302 TA  T     SHUFFLE_WELLDERLY_EA_181            0     /    1
#       179456316 C   CA    SHUFFLE_WELLDERLY_EA_327            0     /    1
#       179456487 CC  CCTTC SHUFFLE_WELLDERLY_EA_82             0     /    1
#       179456573 C   T     SHUFFLE_WELLDERLY_EA_4              0     /    1
#       179456617 G   A     SHUFFLE_WELLDERLY_EA_112            0     /    1
#       179456668 T   C     SHUFFLE_WELLDERLY_EA_262            0     /    1
#
#                                                     GT2     a1   a2 zygosity  \
# CHROM POS       REF ALT   sample_ids
# 2     179392051 CA  CAA   SHUFFLE_WELLDERLY_EA_170    0    CAA   CA  het-ref
#       179392075 GA  GAA   SHUFFLE_WELLDERLY_EA_52     0    GAA   GA  het-ref
#       179392080 A   T     SHUFFLE_WELLDERLY_EA_8      0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_12     0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_13     0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_19     0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_28     0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_29     0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_30     0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_39     0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_41     0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_42     0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_44     0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_45     0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_47     0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_54     0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_60     0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_65     0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_75     0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_81     0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_84     0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_91     0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_96     0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_97     0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_98     0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_107    0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_111    0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_115    0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_121    0      T    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_125    0      T    A  het-ref
# ...                                                 ...    ...  ...      ...
#       179455207 T   C     SHUFFLE_WELLDERLY_EA_441    1      C    C  hom-alt
#                           SHUFFLE_WELLDERLY_EA_442    1      C    C  hom-alt
#       179455303 C   T     SHUFFLE_WELLDERLY_EA_310    0      T    C  het-ref
#       179455352 C   T     SHUFFLE_WELLDERLY_EA_52     0      T    C  het-ref
#                           SHUFFLE_WELLDERLY_EA_150    0      T    C  het-ref
#                           SHUFFLE_WELLDERLY_EA_232    0      T    C  het-ref
#                           SHUFFLE_WELLDERLY_EA_353    0      T    C  het-ref
#                           SHUFFLE_WELLDERLY_EA_393    0      T    C  het-ref
#                           SHUFFLE_WELLDERLY_EA_446    0      T    C  het-ref
#       179455427 T   C     SHUFFLE_WELLDERLY_EA_280    0      C    T  het-ref
#                           SHUFFLE_WELLDERLY_EA_405    0      C    T  het-ref
#       179455502 C   T     SHUFFLE_WELLDERLY_EA_171    0      T    C  het-ref
#       179455631 G   A     SHUFFLE_WELLDERLY_EA_418    0      A    G  het-ref
#       179455731 C   G     SHUFFLE_WELLDERLY_EA_252    0      G    C  het-ref
#                           SHUFFLE_WELLDERLY_EA_310    0      G    C  het-ref
#       179455777 TCC TT    SHUFFLE_WELLDERLY_EA_69     0     TT  TCC  het-ref
#                           SHUFFLE_WELLDERLY_EA_146    0     TT  TCC  het-ref
#       179455928 G   C     SHUFFLE_WELLDERLY_EA_248    0      C    G  het-ref
#       179455936 AG  A     SHUFFLE_WELLDERLY_EA_257    0      A   AG  het-ref
#       179456000 A   G     SHUFFLE_WELLDERLY_EA_383    0      G    A  het-ref
#                           SHUFFLE_WELLDERLY_EA_422    0      G    A  het-ref
#       179456205 T   C     SHUFFLE_WELLDERLY_EA_275    0      C    T  het-ref
#       179456247 G   GA    SHUFFLE_WELLDERLY_EA_276    0     GA    G  het-ref
#       179456264 A   G     SHUFFLE_WELLDERLY_EA_209    0      G    A  het-ref
#       179456302 TA  T     SHUFFLE_WELLDERLY_EA_181    0      T   TA  het-ref
#       179456316 C   CA    SHUFFLE_WELLDERLY_EA_327    0     CA    C  het-ref
#       179456487 CC  CCTTC SHUFFLE_WELLDERLY_EA_82     0  CCTTC   CC  het-ref
#       179456573 C   T     SHUFFLE_WELLDERLY_EA_4      0      T    C  het-ref
#       179456617 G   A     SHUFFLE_WELLDERLY_EA_112    0      A    G  het-ref
#       179456668 T   C     SHUFFLE_WELLDERLY_EA_262    0      C    T  het-ref
#
#                                                    vartype1 vartype2   GT  \
# CHROM POS       REF ALT   sample_ids
# 2     179392051 CA  CAA   SHUFFLE_WELLDERLY_EA_170      ins      ref  1/0
#       179392075 GA  GAA   SHUFFLE_WELLDERLY_EA_52       ins      ref  1/0
#       179392080 A   T     SHUFFLE_WELLDERLY_EA_8        snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_12       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_13       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_19       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_28       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_29       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_30       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_39       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_41       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_42       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_44       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_45       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_47       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_54       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_60       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_65       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_75       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_81       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_84       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_91       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_96       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_97       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_98       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_107      snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_111      snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_115      snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_121      snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_125      snp      ref  1/0
# ...                                                     ...      ...  ...
#       179455207 T   C     SHUFFLE_WELLDERLY_EA_441      snp      snp  1/1
#                           SHUFFLE_WELLDERLY_EA_442      snp      snp  1/1
#       179455303 C   T     SHUFFLE_WELLDERLY_EA_310      snp      ref  1/0
#       179455352 C   T     SHUFFLE_WELLDERLY_EA_52       snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_150      snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_232      snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_353      snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_393      snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_446      snp      ref  1/0
#       179455427 T   C     SHUFFLE_WELLDERLY_EA_280      snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_405      snp      ref  1/0
#       179455502 C   T     SHUFFLE_WELLDERLY_EA_171      snp      ref  1/0
#       179455631 G   A     SHUFFLE_WELLDERLY_EA_418      snp      ref  1/0
#       179455731 C   G     SHUFFLE_WELLDERLY_EA_252      snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_310      snp      ref  1/0
#       179455777 TCC TT    SHUFFLE_WELLDERLY_EA_69     indel      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_146    indel      ref  1/0
#       179455928 G   C     SHUFFLE_WELLDERLY_EA_248      snp      ref  1/0
#       179455936 AG  A     SHUFFLE_WELLDERLY_EA_257      del      ref  1/0
#       179456000 A   G     SHUFFLE_WELLDERLY_EA_383      snp      ref  1/0
#                           SHUFFLE_WELLDERLY_EA_422      snp      ref  1/0
#       179456205 T   C     SHUFFLE_WELLDERLY_EA_275      snp      ref  1/0
#       179456247 G   GA    SHUFFLE_WELLDERLY_EA_276      ins      ref  1/0
#       179456264 A   G     SHUFFLE_WELLDERLY_EA_209      snp      ref  1/0
#       179456302 TA  T     SHUFFLE_WELLDERLY_EA_181      del      ref  1/0
#       179456316 C   CA    SHUFFLE_WELLDERLY_EA_327      ins      ref  1/0
#       179456487 CC  CCTTC SHUFFLE_WELLDERLY_EA_82       ins      ref  1/0
#       179456573 C   T     SHUFFLE_WELLDERLY_EA_4        snp      ref  1/0
#       179456617 G   A     SHUFFLE_WELLDERLY_EA_112      snp      ref  1/0
#       179456668 T   C     SHUFFLE_WELLDERLY_EA_262      snp      ref  1/0
#
#                                                                FORMAT  \
# CHROM POS       REF ALT   sample_ids
# 2     179392051 CA  CAA   SHUFFLE_WELLDERLY_EA_170  GT:FT:GQ:HQ:DP:AD
#       179392075 GA  GAA   SHUFFLE_WELLDERLY_EA_52   GT:FT:GQ:HQ:DP:AD
#       179392080 A   T     SHUFFLE_WELLDERLY_EA_8    GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_12   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_13   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_19   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_28   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_29   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_30   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_39   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_41   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_42   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_44   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_45   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_47   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_54   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_60   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_65   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_75   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_81   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_84   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_91   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_96   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_97   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_98   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_107  GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_111  GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_115  GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_121  GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_125  GT:FT:GQ:HQ:DP:AD
# ...                                                               ...
#       179455207 T   C     SHUFFLE_WELLDERLY_EA_441  GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_442  GT:FT:GQ:HQ:DP:AD
#       179455303 C   T     SHUFFLE_WELLDERLY_EA_310  GT:FT:GQ:HQ:DP:AD
#       179455352 C   T     SHUFFLE_WELLDERLY_EA_52   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_150  GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_232  GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_353  GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_393  GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_446  GT:FT:GQ:HQ:DP:AD
#       179455427 T   C     SHUFFLE_WELLDERLY_EA_280  GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_405  GT:FT:GQ:HQ:DP:AD
#       179455502 C   T     SHUFFLE_WELLDERLY_EA_171  GT:FT:GQ:HQ:DP:AD
#       179455631 G   A     SHUFFLE_WELLDERLY_EA_418  GT:FT:GQ:HQ:DP:AD
#       179455731 C   G     SHUFFLE_WELLDERLY_EA_252  GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_310  GT:FT:GQ:HQ:DP:AD
#       179455777 TCC TT    SHUFFLE_WELLDERLY_EA_69   GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_146  GT:FT:GQ:HQ:DP:AD
#       179455928 G   C     SHUFFLE_WELLDERLY_EA_248  GT:FT:GQ:HQ:DP:AD
#       179455936 AG  A     SHUFFLE_WELLDERLY_EA_257  GT:FT:GQ:HQ:DP:AD
#       179456000 A   G     SHUFFLE_WELLDERLY_EA_383  GT:FT:GQ:HQ:DP:AD
#                           SHUFFLE_WELLDERLY_EA_422  GT:FT:GQ:HQ:DP:AD
#       179456205 T   C     SHUFFLE_WELLDERLY_EA_275  GT:FT:GQ:HQ:DP:AD
#       179456247 G   GA    SHUFFLE_WELLDERLY_EA_276  GT:FT:GQ:HQ:DP:AD
#       179456264 A   G     SHUFFLE_WELLDERLY_EA_209  GT:FT:GQ:HQ:DP:AD
#       179456302 TA  T     SHUFFLE_WELLDERLY_EA_181  GT:FT:GQ:HQ:DP:AD
#       179456316 C   CA    SHUFFLE_WELLDERLY_EA_327  GT:FT:GQ:HQ:DP:AD
#       179456487 CC  CCTTC SHUFFLE_WELLDERLY_EA_82   GT:FT:GQ:HQ:DP:AD
#       179456573 C   T     SHUFFLE_WELLDERLY_EA_4    GT:FT:GQ:HQ:DP:AD
#       179456617 G   A     SHUFFLE_WELLDERLY_EA_112  GT:FT:GQ:HQ:DP:AD
#       179456668 T   C     SHUFFLE_WELLDERLY_EA_262  GT:FT:GQ:HQ:DP:AD
#
#                                                     hom_ref_counts     FT  \
# CHROM POS       REF ALT   sample_ids
# 2     179392051 CA  CAA   SHUFFLE_WELLDERLY_EA_170             448  VQLOW
#       179392075 GA  GAA   SHUFFLE_WELLDERLY_EA_52              447  VQLOW
#       179392080 A   T     SHUFFLE_WELLDERLY_EA_8               337   PASS
#                           SHUFFLE_WELLDERLY_EA_12              337   PASS
#                           SHUFFLE_WELLDERLY_EA_13              337   PASS
#                           SHUFFLE_WELLDERLY_EA_19              337   PASS
#                           SHUFFLE_WELLDERLY_EA_28              337   PASS
#                           SHUFFLE_WELLDERLY_EA_29              337   PASS
#                           SHUFFLE_WELLDERLY_EA_30              337   PASS
#                           SHUFFLE_WELLDERLY_EA_39              337   PASS
#                           SHUFFLE_WELLDERLY_EA_41              337   PASS
#                           SHUFFLE_WELLDERLY_EA_42              337   PASS
#                           SHUFFLE_WELLDERLY_EA_44              337   PASS
#                           SHUFFLE_WELLDERLY_EA_45              337   PASS
#                           SHUFFLE_WELLDERLY_EA_47              337   PASS
#                           SHUFFLE_WELLDERLY_EA_54              337   PASS
#                           SHUFFLE_WELLDERLY_EA_60              337   PASS
#                           SHUFFLE_WELLDERLY_EA_65              337   PASS
#                           SHUFFLE_WELLDERLY_EA_75              337   PASS
#                           SHUFFLE_WELLDERLY_EA_81              337   PASS
#                           SHUFFLE_WELLDERLY_EA_84              337   PASS
#                           SHUFFLE_WELLDERLY_EA_91              337   PASS
#                           SHUFFLE_WELLDERLY_EA_96              337   PASS
#                           SHUFFLE_WELLDERLY_EA_97              337   PASS
#                           SHUFFLE_WELLDERLY_EA_98              337   PASS
#                           SHUFFLE_WELLDERLY_EA_107             337   PASS
#                           SHUFFLE_WELLDERLY_EA_111             337   PASS
#                           SHUFFLE_WELLDERLY_EA_115             337   PASS
#                           SHUFFLE_WELLDERLY_EA_121             337   PASS
#                           SHUFFLE_WELLDERLY_EA_125             337   PASS
# ...                                                            ...    ...
#       179455207 T   C     SHUFFLE_WELLDERLY_EA_441             279   PASS
#                           SHUFFLE_WELLDERLY_EA_442             279   PASS
#       179455303 C   T     SHUFFLE_WELLDERLY_EA_310             453  VQLOW
#       179455352 C   T     SHUFFLE_WELLDERLY_EA_52              448   PASS
#                           SHUFFLE_WELLDERLY_EA_150             448   PASS
#                           SHUFFLE_WELLDERLY_EA_232             448   PASS
#                           SHUFFLE_WELLDERLY_EA_353             448   PASS
#                           SHUFFLE_WELLDERLY_EA_393             448   PASS
#                           SHUFFLE_WELLDERLY_EA_446             448   PASS
#       179455427 T   C     SHUFFLE_WELLDERLY_EA_280             452  VQLOW
#                           SHUFFLE_WELLDERLY_EA_405             452  VQLOW
#       179455502 C   T     SHUFFLE_WELLDERLY_EA_171             453   PASS
#       179455631 G   A     SHUFFLE_WELLDERLY_EA_418             453   PASS
#       179455731 C   G     SHUFFLE_WELLDERLY_EA_252             452   PASS
#                           SHUFFLE_WELLDERLY_EA_310             452   PASS
#       179455777 TCC TT    SHUFFLE_WELLDERLY_EA_69              451  VQLOW
#                           SHUFFLE_WELLDERLY_EA_146             451   PASS
#       179455928 G   C     SHUFFLE_WELLDERLY_EA_248             453   PASS
#       179455936 AG  A     SHUFFLE_WELLDERLY_EA_257             453  VQLOW
#       179456000 A   G     SHUFFLE_WELLDERLY_EA_383             452  VQLOW
#                           SHUFFLE_WELLDERLY_EA_422             452  VQLOW
#       179456205 T   C     SHUFFLE_WELLDERLY_EA_275             453  VQLOW
#       179456247 G   GA    SHUFFLE_WELLDERLY_EA_276             450  VQLOW
#       179456264 A   G     SHUFFLE_WELLDERLY_EA_209             451  VQLOW
#       179456302 TA  T     SHUFFLE_WELLDERLY_EA_181             453  VQLOW
#       179456316 C   CA    SHUFFLE_WELLDERLY_EA_327             453  VQLOW
#       179456487 CC  CCTTC SHUFFLE_WELLDERLY_EA_82              450  VQLOW
#       179456573 C   T     SHUFFLE_WELLDERLY_EA_4               453  VQLOW
#       179456617 G   A     SHUFFLE_WELLDERLY_EA_112             453  VQLOW
#       179456668 T   C     SHUFFLE_WELLDERLY_EA_262             453   PASS
#
#                                                      GQ        HQ   DP     AD
# CHROM POS       REF ALT   sample_ids
# 2     179392051 CA  CAA   SHUFFLE_WELLDERLY_EA_170   20     20,20   30   3,27
#       179392075 GA  GAA   SHUFFLE_WELLDERLY_EA_52    20     20,20   34   6,28
#       179392080 A   T     SHUFFLE_WELLDERLY_EA_8    359   454,359   49  26,23
#                           SHUFFLE_WELLDERLY_EA_12   248   248,248   30  14,16
#                           SHUFFLE_WELLDERLY_EA_13   206   206,206   28  12,16
#                           SHUFFLE_WELLDERLY_EA_19   463   629,463   56  31,25
#                           SHUFFLE_WELLDERLY_EA_28   273   388,273   38  23,15
#                           SHUFFLE_WELLDERLY_EA_29   344   344,344   34  17,17
#                           SHUFFLE_WELLDERLY_EA_30   240   240,277   52  17,35
#                           SHUFFLE_WELLDERLY_EA_39   423   423,423   67  24,43
#                           SHUFFLE_WELLDERLY_EA_41   481   481,481   59  26,33
#                           SHUFFLE_WELLDERLY_EA_42   298   494,298   40  24,16
#                           SHUFFLE_WELLDERLY_EA_44   180   180,180   28  10,18
#                           SHUFFLE_WELLDERLY_EA_45   354   354,354   56  22,34
#                           SHUFFLE_WELLDERLY_EA_47   644   644,644   74  33,41
#                           SHUFFLE_WELLDERLY_EA_54   210   210,210   44  15,29
#                           SHUFFLE_WELLDERLY_EA_60   355   656,355   50  33,17
#                           SHUFFLE_WELLDERLY_EA_65   340   340,340   33  17,16
#                           SHUFFLE_WELLDERLY_EA_75   897   897,897  104  53,51
#                           SHUFFLE_WELLDERLY_EA_81   454   456,454   49  25,24
#                           SHUFFLE_WELLDERLY_EA_84   261   261,261   38  15,23
#                           SHUFFLE_WELLDERLY_EA_91   370   370,370   39  20,19
#                           SHUFFLE_WELLDERLY_EA_96   372   478,372   41  23,18
#                           SHUFFLE_WELLDERLY_EA_97   641   826,641   75  40,35
#                           SHUFFLE_WELLDERLY_EA_98   351   351,395   44  21,23
#                           SHUFFLE_WELLDERLY_EA_107  376   532,376   46  26,20
#                           SHUFFLE_WELLDERLY_EA_111  506   506,506   54  25,29
#                           SHUFFLE_WELLDERLY_EA_115  353   353,353   42  18,24
#                           SHUFFLE_WELLDERLY_EA_121  345   345,345   37  18,19
#                           SHUFFLE_WELLDERLY_EA_125  509   551,509   54  28,26
# ...                                                 ...       ...  ...    ...
#       179455207 T   C     SHUFFLE_WELLDERLY_EA_441  171  1606,171   68  68,68
#                           SHUFFLE_WELLDERLY_EA_442  164  1424,164   54  54,54
#       179455303 C   T     SHUFFLE_WELLDERLY_EA_310   20     20,20   41   4,37
#       179455352 C   T     SHUFFLE_WELLDERLY_EA_52   372   372,372   50  22,28
#                           SHUFFLE_WELLDERLY_EA_150  517   517,517   61  25,36
#                           SHUFFLE_WELLDERLY_EA_232  655   715,655   74  38,36
#                           SHUFFLE_WELLDERLY_EA_353  318   488,318   39  23,16
#                           SHUFFLE_WELLDERLY_EA_393  320   497,320   45  26,19
#                           SHUFFLE_WELLDERLY_EA_446  554   583,554   58  28,30
#       179455427 T   C     SHUFFLE_WELLDERLY_EA_280   36     36,36   32   4,28
#                           SHUFFLE_WELLDERLY_EA_405   38     38,38   35   4,31
#       179455502 C   T     SHUFFLE_WELLDERLY_EA_171   92     92,92   48   7,41
#       179455631 G   A     SHUFFLE_WELLDERLY_EA_418  306   306,306   32  15,17
#       179455731 C   G     SHUFFLE_WELLDERLY_EA_252  642   642,642   80  33,47
#                           SHUFFLE_WELLDERLY_EA_310  468   468,468   47  25,22
#       179455777 TCC TT    SHUFFLE_WELLDERLY_EA_69    38     38,38   48   3,45
#                           SHUFFLE_WELLDERLY_EA_146   74     74,74   72   5,67
#       179455928 G   C     SHUFFLE_WELLDERLY_EA_248  241   241,241   28  12,16
#       179455936 AG  A     SHUFFLE_WELLDERLY_EA_257   22     22,22   59   5,54
#       179456000 A   G     SHUFFLE_WELLDERLY_EA_383   27     27,27   46   6,40
#                           SHUFFLE_WELLDERLY_EA_422   26     26,26   49   5,44
#       179456205 T   C     SHUFFLE_WELLDERLY_EA_275   23     23,23   40   5,35
#       179456247 G   GA    SHUFFLE_WELLDERLY_EA_276   25     25,25   33   8,25
#       179456264 A   G     SHUFFLE_WELLDERLY_EA_209   28     28,28   47   4,43
#       179456302 TA  T     SHUFFLE_WELLDERLY_EA_181   26     26,26   35   5,30
#       179456316 C   CA    SHUFFLE_WELLDERLY_EA_327   21     21,21   30   4,26
#       179456487 CC  CCTTC SHUFFLE_WELLDERLY_EA_82    21     21,21   28   3,25
#       179456573 C   T     SHUFFLE_WELLDERLY_EA_4     21     21,21   29   4,25
#       179456617 G   A     SHUFFLE_WELLDERLY_EA_112   36     36,36   37   3,34
#       179456668 T   C     SHUFFLE_WELLDERLY_EA_262   43     43,43   41   7,34
#
# [8070 rows x 17 columns]

# %%
vcf_chunk.df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 8070 entries, (2, 179392051, CA, CAA, SHUFFLE_WELLDERLY_EA_170) to (2, 179456668, T, C, SHUFFLE_WELLDERLY_EA_262)
# Data columns (total 17 columns):
# multiallele       8070 non-null int64
# phase             8070 non-null object
# GT1               8070 non-null int64
# GT2               8070 non-null int64
# a1                8070 non-null object
# a2                8070 non-null object
# zygosity          8070 non-null object
# vartype1          8070 non-null object
# vartype2          8070 non-null object
# GT                8070 non-null object
# FORMAT            8070 non-null object
# hom_ref_counts    8070 non-null float64
# FT                8070 non-null object
# GQ                8070 non-null object
# HQ                8070 non-null object
# DP                8070 non-null object
# AD                8070 non-null object
# dtypes: float64(1), int64(3), object(13)
# memory usage: 1.1 MB

# %%
vcf_chunk.df.head()
# Out:
#                                                   multiallele phase  GT1  GT2  \
# CHROM POS       REF ALT sample_ids
# 2     179392051 CA  CAA SHUFFLE_WELLDERLY_EA_170            0     /    1    0
#       179392075 GA  GAA SHUFFLE_WELLDERLY_EA_52             0     /    1    0
#       179392080 A   T   SHUFFLE_WELLDERLY_EA_8              0     /    1    0
#                         SHUFFLE_WELLDERLY_EA_12             0     /    1    0
#                         SHUFFLE_WELLDERLY_EA_13             0     /    1    0
#
#                                                    a1  a2 zygosity vartype1  \
# CHROM POS       REF ALT sample_ids
# 2     179392051 CA  CAA SHUFFLE_WELLDERLY_EA_170  CAA  CA  het-ref      ins
#       179392075 GA  GAA SHUFFLE_WELLDERLY_EA_52   GAA  GA  het-ref      ins
#       179392080 A   T   SHUFFLE_WELLDERLY_EA_8      T   A  het-ref      snp
#                         SHUFFLE_WELLDERLY_EA_12     T   A  het-ref      snp
#                         SHUFFLE_WELLDERLY_EA_13     T   A  het-ref      snp
#
#                                                  vartype2   GT  \
# CHROM POS       REF ALT sample_ids
# 2     179392051 CA  CAA SHUFFLE_WELLDERLY_EA_170      ref  1/0
#       179392075 GA  GAA SHUFFLE_WELLDERLY_EA_52       ref  1/0
#       179392080 A   T   SHUFFLE_WELLDERLY_EA_8        ref  1/0
#                         SHUFFLE_WELLDERLY_EA_12       ref  1/0
#                         SHUFFLE_WELLDERLY_EA_13       ref  1/0
#
#                                                              FORMAT  \
# CHROM POS       REF ALT sample_ids
# 2     179392051 CA  CAA SHUFFLE_WELLDERLY_EA_170  GT:FT:GQ:HQ:DP:AD
#       179392075 GA  GAA SHUFFLE_WELLDERLY_EA_52   GT:FT:GQ:HQ:DP:AD
#       179392080 A   T   SHUFFLE_WELLDERLY_EA_8    GT:FT:GQ:HQ:DP:AD
#                         SHUFFLE_WELLDERLY_EA_12   GT:FT:GQ:HQ:DP:AD
#                         SHUFFLE_WELLDERLY_EA_13   GT:FT:GQ:HQ:DP:AD
#
#                                                   hom_ref_counts     FT   GQ  \
# CHROM POS       REF ALT sample_ids
# 2     179392051 CA  CAA SHUFFLE_WELLDERLY_EA_170             448  VQLOW   20
#       179392075 GA  GAA SHUFFLE_WELLDERLY_EA_52              447  VQLOW   20
#       179392080 A   T   SHUFFLE_WELLDERLY_EA_8               337   PASS  359
#                         SHUFFLE_WELLDERLY_EA_12              337   PASS  248
#                         SHUFFLE_WELLDERLY_EA_13              337   PASS  206
#
#                                                        HQ  DP     AD
# CHROM POS       REF ALT sample_ids
# 2     179392051 CA  CAA SHUFFLE_WELLDERLY_EA_170    20,20  30   3,27
#       179392075 GA  GAA SHUFFLE_WELLDERLY_EA_52     20,20  34   6,28
#       179392080 A   T   SHUFFLE_WELLDERLY_EA_8    454,359  49  26,23
#                         SHUFFLE_WELLDERLY_EA_12   248,248  30  14,16
#                         SHUFFLE_WELLDERLY_EA_13   206,206  28  12,16

# %% [markdown]
# ### Unstacking the parsed dataframe by sample leads to sparsity due to rare variants

# %%
#unstack dataframe by sample - QUITE SPARSE DUE TO RARE VARIANTS
vcf_chunk.df.unstack(level=4).tail()
# Out:
#                                      multiallele                         \
# sample_ids                SHUFFLE_WELLDERLY_EA_0 SHUFFLE_WELLDERLY_EA_1
# CHROM POS       REF ALT
# 2     179456316 C   CA                       NaN                    NaN
#       179456487 CC  CCTTC                    NaN                    NaN
#       179456573 C   T                        NaN                    NaN
#       179456617 G   A                        NaN                    NaN
#       179456668 T   C                        NaN                    NaN
#
#                                                                             \
# sample_ids                SHUFFLE_WELLDERLY_EA_10 SHUFFLE_WELLDERLY_EA_100
# CHROM POS       REF ALT
# 2     179456316 C   CA                        NaN                      NaN
#       179456487 CC  CCTTC                     NaN                      NaN
#       179456573 C   T                         NaN                      NaN
#       179456617 G   A                         NaN                      NaN
#       179456668 T   C                         NaN                      NaN
#
#                                                                              \
# sample_ids                SHUFFLE_WELLDERLY_EA_101 SHUFFLE_WELLDERLY_EA_102
# CHROM POS       REF ALT
# 2     179456316 C   CA                         NaN                      NaN
#       179456487 CC  CCTTC                      NaN                      NaN
#       179456573 C   T                          NaN                      NaN
#       179456617 G   A                          NaN                      NaN
#       179456668 T   C                          NaN                      NaN
#
#                                                                              \
# sample_ids                SHUFFLE_WELLDERLY_EA_103 SHUFFLE_WELLDERLY_EA_104
# CHROM POS       REF ALT
# 2     179456316 C   CA                         NaN                      NaN
#       179456487 CC  CCTTC                      NaN                      NaN
#       179456573 C   T                          NaN                      NaN
#       179456617 G   A                          NaN                      NaN
#       179456668 T   C                          NaN                      NaN
#
#                                                                              \
# sample_ids                SHUFFLE_WELLDERLY_EA_105 SHUFFLE_WELLDERLY_EA_106
# CHROM POS       REF ALT
# 2     179456316 C   CA                         NaN                      NaN
#       179456487 CC  CCTTC                      NaN                      NaN
#       179456573 C   T                          NaN                      NaN
#       179456617 G   A                          NaN                      NaN
#       179456668 T   C                          NaN                      NaN
#
#                                     ...                                AD  \
# sample_ids                          ...           SHUFFLE_WELLDERLY_EA_90
# CHROM POS       REF ALT             ...
# 2     179456316 C   CA              ...                               NaN
#       179456487 CC  CCTTC           ...                               NaN
#       179456573 C   T               ...                               NaN
#       179456617 G   A               ...                               NaN
#       179456668 T   C               ...                               NaN
#
#                                                                            \
# sample_ids                SHUFFLE_WELLDERLY_EA_91 SHUFFLE_WELLDERLY_EA_92
# CHROM POS       REF ALT
# 2     179456316 C   CA                        NaN                     NaN
#       179456487 CC  CCTTC                     NaN                     NaN
#       179456573 C   T                         NaN                     NaN
#       179456617 G   A                         NaN                     NaN
#       179456668 T   C                         NaN                     NaN
#
#                                                                            \
# sample_ids                SHUFFLE_WELLDERLY_EA_93 SHUFFLE_WELLDERLY_EA_94
# CHROM POS       REF ALT
# 2     179456316 C   CA                        NaN                     NaN
#       179456487 CC  CCTTC                     NaN                     NaN
#       179456573 C   T                         NaN                     NaN
#       179456617 G   A                         NaN                     NaN
#       179456668 T   C                         NaN                     NaN
#
#                                                                            \
# sample_ids                SHUFFLE_WELLDERLY_EA_95 SHUFFLE_WELLDERLY_EA_96
# CHROM POS       REF ALT
# 2     179456316 C   CA                        NaN                     NaN
#       179456487 CC  CCTTC                     NaN                     NaN
#       179456573 C   T                         NaN                     NaN
#       179456617 G   A                         NaN                     NaN
#       179456668 T   C                         NaN                     NaN
#
#                                                                            \
# sample_ids                SHUFFLE_WELLDERLY_EA_97 SHUFFLE_WELLDERLY_EA_98
# CHROM POS       REF ALT
# 2     179456316 C   CA                        NaN                     NaN
#       179456487 CC  CCTTC                     NaN                     NaN
#       179456573 C   T                         NaN                     NaN
#       179456617 G   A                         NaN                     NaN
#       179456668 T   C                         NaN                     NaN
#
#
# sample_ids                SHUFFLE_WELLDERLY_EA_99
# CHROM POS       REF ALT
# 2     179456316 C   CA                        NaN
#       179456487 CC  CCTTC                     NaN
#       179456573 C   T                         NaN
#       179456617 G   A                         NaN
#       179456668 T   C                         NaN
#
# [5 rows x 7718 columns]

# %% [markdown]
# ## CONVENINCE FUNCTION FOR PARSING AN ENTIRE MULTISAMPLE FILE

# %%
def get_whole_file(vcf_path, sample_ids='all', columns=['#CHROM', 'POS', 'REF', 'ALT', 'FORMAT'], \
                   add_variant_annotations=True, split_columns='', chunksize=5000, inplace=True, n_cores=1):
    '''
    This function will parse the whole multi-sample vcf file
    and return a dataframe.
    
    Note using multiple cores with add_variant_annotations will be 
    very memory intensive as the parsed dataframe is copied to each process.
    '''
    
    vcf_df_obj = Vcf(vcf_path, sample_id=sample_ids, cols=columns, chunksize=chunksize, n_cores=n_cores)  #initiate object
    stopIteration = False  #initiating stopIteration flag
    data = []  #aggregation df list
    
    while stopIteration == False:

        vcf_df_obj.get_vcf_df_chunk()  #retrieving df chunk
        if vcf_df_obj.stopIteration == True: break  #checking for end of file
        
        if add_variant_annotations:  
            vcf_df_obj.add_variant_annotations(split_columns=split_columns, inplace=inplace)  #parsing df and adding annotations
            if inplace:
                data.append(vcf_df_obj.df)
            else:
                data.append(vcf_df_obj.df_annot)  #aggregating annotation data
        else:
            vcf_df_obj.append(vcf_df_obj.df)

    df = pd.concat(data)
    return df

# %%
vcf_path
# Out:
# '../test_data/SWGR_titin.vcf.gz'

# %%
master_df = get_whole_file(vcf_path, sample_ids='all', columns=['#CHROM', 'POS', 'REF', 'ALT','FORMAT'], \
                           chunksize=5000, n_cores=1)
# Out:
# End of File Reached

# %%
master_df.zygosity.value_counts().plot(kind='bar', log=True)

# %%
master_df.vartype2.value_counts()
# Out:
# ref      31553
# snp      24159
# ins        681
# mnp        367
# del        215
# indel       63
# dtype: int64

# %%
len(master_df)
# Out:
# 57038

# %%
master_df.head(20)
# Out:
#                                                   multiallele phase  GT1  GT2  \
# CHROM POS       REF ALT sample_ids
# 2     179392051 CA  CAA SHUFFLE_WELLDERLY_EA_170            0     /    1    0
#       179392075 GA  GAA SHUFFLE_WELLDERLY_EA_52             0     /    1    0
#       179392080 A   T   SHUFFLE_WELLDERLY_EA_8              0     /    1    0
#                         SHUFFLE_WELLDERLY_EA_12             0     /    1    0
#                         SHUFFLE_WELLDERLY_EA_13             0     /    1    0
#                         SHUFFLE_WELLDERLY_EA_19             0     /    1    0
#                         SHUFFLE_WELLDERLY_EA_28             0     /    1    0
#                         SHUFFLE_WELLDERLY_EA_29             0     /    1    0
#                         SHUFFLE_WELLDERLY_EA_30             0     /    1    0
#                         SHUFFLE_WELLDERLY_EA_39             0     /    1    0
#                         SHUFFLE_WELLDERLY_EA_41             0     /    1    0
#                         SHUFFLE_WELLDERLY_EA_42             0     /    1    0
#                         SHUFFLE_WELLDERLY_EA_44             0     /    1    0
#                         SHUFFLE_WELLDERLY_EA_45             0     /    1    0
#                         SHUFFLE_WELLDERLY_EA_47             0     /    1    0
#                         SHUFFLE_WELLDERLY_EA_54             0     /    1    0
#                         SHUFFLE_WELLDERLY_EA_60             0     /    1    0
#                         SHUFFLE_WELLDERLY_EA_65             0     /    1    0
#                         SHUFFLE_WELLDERLY_EA_75             0     /    1    0
#                         SHUFFLE_WELLDERLY_EA_81             0     /    1    0
#
#                                                    a1  a2 zygosity vartype1  \
# CHROM POS       REF ALT sample_ids
# 2     179392051 CA  CAA SHUFFLE_WELLDERLY_EA_170  CAA  CA  het-ref      ins
#       179392075 GA  GAA SHUFFLE_WELLDERLY_EA_52   GAA  GA  het-ref      ins
#       179392080 A   T   SHUFFLE_WELLDERLY_EA_8      T   A  het-ref      snp
#                         SHUFFLE_WELLDERLY_EA_12     T   A  het-ref      snp
#                         SHUFFLE_WELLDERLY_EA_13     T   A  het-ref      snp
#                         SHUFFLE_WELLDERLY_EA_19     T   A  het-ref      snp
#                         SHUFFLE_WELLDERLY_EA_28     T   A  het-ref      snp
#                         SHUFFLE_WELLDERLY_EA_29     T   A  het-ref      snp
#                         SHUFFLE_WELLDERLY_EA_30     T   A  het-ref      snp
#                         SHUFFLE_WELLDERLY_EA_39     T   A  het-ref      snp
#                         SHUFFLE_WELLDERLY_EA_41     T   A  het-ref      snp
#                         SHUFFLE_WELLDERLY_EA_42     T   A  het-ref      snp
#                         SHUFFLE_WELLDERLY_EA_44     T   A  het-ref      snp
#                         SHUFFLE_WELLDERLY_EA_45     T   A  het-ref      snp
#                         SHUFFLE_WELLDERLY_EA_47     T   A  het-ref      snp
#                         SHUFFLE_WELLDERLY_EA_54     T   A  het-ref      snp
#                         SHUFFLE_WELLDERLY_EA_60     T   A  het-ref      snp
#                         SHUFFLE_WELLDERLY_EA_65     T   A  het-ref      snp
#                         SHUFFLE_WELLDERLY_EA_75     T   A  het-ref      snp
#                         SHUFFLE_WELLDERLY_EA_81     T   A  het-ref      snp
#
#                                                  vartype2   GT  \
# CHROM POS       REF ALT sample_ids
# 2     179392051 CA  CAA SHUFFLE_WELLDERLY_EA_170      ref  1/0
#       179392075 GA  GAA SHUFFLE_WELLDERLY_EA_52       ref  1/0
#       179392080 A   T   SHUFFLE_WELLDERLY_EA_8        ref  1/0
#                         SHUFFLE_WELLDERLY_EA_12       ref  1/0
#                         SHUFFLE_WELLDERLY_EA_13       ref  1/0
#                         SHUFFLE_WELLDERLY_EA_19       ref  1/0
#                         SHUFFLE_WELLDERLY_EA_28       ref  1/0
#                         SHUFFLE_WELLDERLY_EA_29       ref  1/0
#                         SHUFFLE_WELLDERLY_EA_30       ref  1/0
#                         SHUFFLE_WELLDERLY_EA_39       ref  1/0
#                         SHUFFLE_WELLDERLY_EA_41       ref  1/0
#                         SHUFFLE_WELLDERLY_EA_42       ref  1/0
#                         SHUFFLE_WELLDERLY_EA_44       ref  1/0
#                         SHUFFLE_WELLDERLY_EA_45       ref  1/0
#                         SHUFFLE_WELLDERLY_EA_47       ref  1/0
#                         SHUFFLE_WELLDERLY_EA_54       ref  1/0
#                         SHUFFLE_WELLDERLY_EA_60       ref  1/0
#                         SHUFFLE_WELLDERLY_EA_65       ref  1/0
#                         SHUFFLE_WELLDERLY_EA_75       ref  1/0
#                         SHUFFLE_WELLDERLY_EA_81       ref  1/0
#
#                                                              FORMAT  \
# CHROM POS       REF ALT sample_ids
# 2     179392051 CA  CAA SHUFFLE_WELLDERLY_EA_170  GT:FT:GQ:HQ:DP:AD
#       179392075 GA  GAA SHUFFLE_WELLDERLY_EA_52   GT:FT:GQ:HQ:DP:AD
#       179392080 A   T   SHUFFLE_WELLDERLY_EA_8    GT:FT:GQ:HQ:DP:AD
#                         SHUFFLE_WELLDERLY_EA_12   GT:FT:GQ:HQ:DP:AD
#                         SHUFFLE_WELLDERLY_EA_13   GT:FT:GQ:HQ:DP:AD
#                         SHUFFLE_WELLDERLY_EA_19   GT:FT:GQ:HQ:DP:AD
#                         SHUFFLE_WELLDERLY_EA_28   GT:FT:GQ:HQ:DP:AD
#                         SHUFFLE_WELLDERLY_EA_29   GT:FT:GQ:HQ:DP:AD
#                         SHUFFLE_WELLDERLY_EA_30   GT:FT:GQ:HQ:DP:AD
#                         SHUFFLE_WELLDERLY_EA_39   GT:FT:GQ:HQ:DP:AD
#                         SHUFFLE_WELLDERLY_EA_41   GT:FT:GQ:HQ:DP:AD
#                         SHUFFLE_WELLDERLY_EA_42   GT:FT:GQ:HQ:DP:AD
#                         SHUFFLE_WELLDERLY_EA_44   GT:FT:GQ:HQ:DP:AD
#                         SHUFFLE_WELLDERLY_EA_45   GT:FT:GQ:HQ:DP:AD
#                         SHUFFLE_WELLDERLY_EA_47   GT:FT:GQ:HQ:DP:AD
#                         SHUFFLE_WELLDERLY_EA_54   GT:FT:GQ:HQ:DP:AD
#                         SHUFFLE_WELLDERLY_EA_60   GT:FT:GQ:HQ:DP:AD
#                         SHUFFLE_WELLDERLY_EA_65   GT:FT:GQ:HQ:DP:AD
#                         SHUFFLE_WELLDERLY_EA_75   GT:FT:GQ:HQ:DP:AD
#                         SHUFFLE_WELLDERLY_EA_81   GT:FT:GQ:HQ:DP:AD
#
#                                                   hom_ref_counts     FT   GQ  \
# CHROM POS       REF ALT sample_ids
# 2     179392051 CA  CAA SHUFFLE_WELLDERLY_EA_170             448  VQLOW   20
#       179392075 GA  GAA SHUFFLE_WELLDERLY_EA_52              447  VQLOW   20
#       179392080 A   T   SHUFFLE_WELLDERLY_EA_8               337   PASS  359
#                         SHUFFLE_WELLDERLY_EA_12              337   PASS  248
#                         SHUFFLE_WELLDERLY_EA_13              337   PASS  206
#                         SHUFFLE_WELLDERLY_EA_19              337   PASS  463
#                         SHUFFLE_WELLDERLY_EA_28              337   PASS  273
#                         SHUFFLE_WELLDERLY_EA_29              337   PASS  344
#                         SHUFFLE_WELLDERLY_EA_30              337   PASS  240
#                         SHUFFLE_WELLDERLY_EA_39              337   PASS  423
#                         SHUFFLE_WELLDERLY_EA_41              337   PASS  481
#                         SHUFFLE_WELLDERLY_EA_42              337   PASS  298
#                         SHUFFLE_WELLDERLY_EA_44              337   PASS  180
#                         SHUFFLE_WELLDERLY_EA_45              337   PASS  354
#                         SHUFFLE_WELLDERLY_EA_47              337   PASS  644
#                         SHUFFLE_WELLDERLY_EA_54              337   PASS  210
#                         SHUFFLE_WELLDERLY_EA_60              337   PASS  355
#                         SHUFFLE_WELLDERLY_EA_65              337   PASS  340
#                         SHUFFLE_WELLDERLY_EA_75              337   PASS  897
#                         SHUFFLE_WELLDERLY_EA_81              337   PASS  454
#
#                                                        HQ   DP     AD
# CHROM POS       REF ALT sample_ids
# 2     179392051 CA  CAA SHUFFLE_WELLDERLY_EA_170    20,20   30   3,27
#       179392075 GA  GAA SHUFFLE_WELLDERLY_EA_52     20,20   34   6,28
#       179392080 A   T   SHUFFLE_WELLDERLY_EA_8    454,359   49  26,23
#                         SHUFFLE_WELLDERLY_EA_12   248,248   30  14,16
#                         SHUFFLE_WELLDERLY_EA_13   206,206   28  12,16
#                         SHUFFLE_WELLDERLY_EA_19   629,463   56  31,25
#                         SHUFFLE_WELLDERLY_EA_28   388,273   38  23,15
#                         SHUFFLE_WELLDERLY_EA_29   344,344   34  17,17
#                         SHUFFLE_WELLDERLY_EA_30   240,277   52  17,35
#                         SHUFFLE_WELLDERLY_EA_39   423,423   67  24,43
#                         SHUFFLE_WELLDERLY_EA_41   481,481   59  26,33
#                         SHUFFLE_WELLDERLY_EA_42   494,298   40  24,16
#                         SHUFFLE_WELLDERLY_EA_44   180,180   28  10,18
#                         SHUFFLE_WELLDERLY_EA_45   354,354   56  22,34
#                         SHUFFLE_WELLDERLY_EA_47   644,644   74  33,41
#                         SHUFFLE_WELLDERLY_EA_54   210,210   44  15,29
#                         SHUFFLE_WELLDERLY_EA_60   656,355   50  33,17
#                         SHUFFLE_WELLDERLY_EA_65   340,340   33  17,16
#                         SHUFFLE_WELLDERLY_EA_75   897,897  104  53,51
#                         SHUFFLE_WELLDERLY_EA_81   456,454   49  25,24
